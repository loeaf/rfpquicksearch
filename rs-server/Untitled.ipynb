# %%
from sklearn.feature_extraction.text import TfidfVectorizer
mydoclist = ['영희가 좋아하는 사람은 철수다.',
            '철수를 영희가 좋아한다.',
            '영희는 철수를 좋아하고 있다.']
tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(mydoclist)
document_distances = (tfidf_matrix * tfidf_matrix.T)

print('우사도 분석을 위한 ' + str(document_distances.get_shape()[0]) + 'x' + str(document_distances.get_shape()[1]) + ' matrix를 만들었습니다.')
print(document_distances.toarray())
# Out:
# 우사도 분석을 위한 3x3 matrix를 만들었습니다.
# [[1.       0.208199 0.      ]
#  [0.208199 1.       0.208199]
#  [0.       0.208199 1.      ]]

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint

kkma = Kkma()

sentence = u'영희와 철수는 백구를 산책시키기 위해 한강에 갔다. 한강에 도착하여 누렁이를 만났다.'

print('형태소 : ' + str(kkma.morphs(sentence)))
print('명사 : ' + str(kkma.nouns(sentence)))
print('품사 : ' + str(kkma.pos(sentence)))
# Out:
# 형태소 : ['영희', '와', '철수', '는', '백구', '를', '산책', '시키', '기', '위하', '어', '한강', '에', '가', '었', '다', '.', '한강', '에', '도착', '하', '여', '누렁이', '를', '만나', '었', '다', '.']
# 명사 : ['영희', '철수', '백구', '산책', '한강', '도착', '누렁이']
# 품사 : [('영희', 'NNP'), ('와', 'JKM'), ('철수', 'NNG'), ('는', 'JX'), ('백구', 'NNG'), ('를', 'JKO'), ('산책', 'NNG'), ('시키', 'XSV'), ('기', 'ETN'), ('위하', 'VV'), ('어', 'ECS'), ('한강', 'NNP'), ('에', 'JKM'), ('가', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('한강', 'NNP'), ('에', 'JKM'), ('도착', 'NNG'), ('하', 'XSV'), ('여', 'ECS'), ('누렁이', 'NNG'), ('를', 'JKO'), ('만나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF')]

# %%
from konlpy.tag import Twitter
from konlpy.utils import pprint

kkma = Kkma()

sentence = u'영희와 철수는 백구를 산책시키기 위해 한강에 갔다. 한강에 도착하여 누렁이를 만났다.'

print('형태소 : ' + str(kkma.morphs(sentence)))
print('명사 : ' + str(kkma.nouns(sentence)))
print('품사 : ' + str(kkma.pos(sentence)))
# Out:
# 형태소 : ['영희', '와', '철수', '는', '백구', '를', '산책', '시키', '기', '위하', '어', '한강', '에', '가', '었', '다', '.', '한강', '에', '도착', '하', '여', '누렁이', '를', '만나', '었', '다', '.']
# 명사 : ['영희', '철수', '백구', '산책', '한강', '도착', '누렁이']
# 품사 : [('영희', 'NNP'), ('와', 'JKM'), ('철수', 'NNG'), ('는', 'JX'), ('백구', 'NNG'), ('를', 'JKO'), ('산책', 'NNG'), ('시키', 'XSV'), ('기', 'ETN'), ('위하', 'VV'), ('어', 'ECS'), ('한강', 'NNP'), ('에', 'JKM'), ('가', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF'), ('한강', 'NNP'), ('에', 'JKM'), ('도착', 'NNG'), ('하', 'XSV'), ('여', 'ECS'), ('누렁이', 'NNG'), ('를', 'JKO'), ('만나', 'VV'), ('었', 'EPT'), ('다', 'EFN'), ('.', 'SF')]

# %%
from konlpy.tag import Kkma, Twitter
from konlpy.utils import pprint


mydoclist = ['영희가 사랑하는 강아지 백구를 산책시키고 있다.',
'철수가 사랑하는 소 누렁이를 운동시키고 있다',
'영희와 철수는 소와 강아지를 산책 및 운동시키고 있다']

kkma = Kkma()
twitter = Twitter()


print('명사 : ' + str(kkma.nouns(mydoclist[0])))
print('품사 : ' + str(twitter.nouns(mydoclist[0])))
# Out:
# 명사 : ['영희', '사랑', '강아지', '백구', '산책']
# 품사 : ['영희', '사랑', '강아지', '백구', '산책']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Kkma, Twitter
from konlpy.utils import pprint


mydoclist = [
    '영희가 사랑하는 강아지 백구를 산책시키고 있다.',
    '철수가 사랑하는 소 누렁이를 운동시키고 있다',
    '영희와 철수는 소와 강아지를 산책 및 운동시키고 있다']

kkma = Twitter()

doc_nouns_list = []

for doc in mydoclist:
    nouns = kkma.nouns(doc)
    doc_nouns = ''
    
    for noun in nouns:
        doc_nouns += noun + ' '
    doc_nouns_list.append(doc_nouns)

for i in range(0, 3):
    print('doc' + str(i + 1) + ' : ' + str(doc_nouns_list[i]))
print(doc_nouns_list)
# Out:
# doc1 : 영희 사랑 강아지 백구 산책
# doc2 : 철수 사랑 소 누렁이 운동
# doc3 : 영희 철수 소 강아지 산책 및 운동
# ['영희 사랑 강아지 백구 산책 ', '철수 사랑 소 누렁이 운동 ', '영희 철수 소 강아지 산책 및 운동 ']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_nouns_list)
document_distances = (tfidf_matrix * tfidf_matrix.T)

print('우사도 분석을 위한 ' + str(document_distances.get_shape()[0]) + 'x' + str(document_distances.get_shape()[1]) + ' matrix를 만들었습니다.')
print(document_distances.toarray())
# Out:
# 우사도 분석을 위한 3x3 matrix를 만들었습니다.
# [[1.         0.19212486 0.56053185]
#  [0.19212486 1.         0.4113055 ]
#  [0.56053185 0.4113055  1.        ]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Kkma, Twitter
from konlpy.utils import pprint

# 0 번째는 검증하고 싶은 문자.
# n 번째는 대조군
mydoclist = [
    '이행 및 승인테스트에 대한 계획을 기술하여야 함  테스트 단계별로 수행방법, 절차, 참여 조직 및 역할, 점검사항, 최종 검수 기준, 점검 후 조치 방안 및 대량자료 테스트 수행방안 등을 세부적으로 기술하여야 함 계약상대자는 발주기관과 협의하여 승인테스트를 계획하고, 발주기관이 승인테스트를 이행하기 위하여 필요한 모든 조력을 제공하여야 함 ',
    '제안사는 본 사업을 기간 내에 완수하기 위해 단계별 추진일정 등이 포함된 일정계획을 제시하여야 함 착수보고서 제출 시 사업 진행의 모든 일정이 명시된 사업 일정계획표(WBS)를 함께 제출 후 발주기관의 승인을 받아야 함 제안사는 일정계획에 따른 관리방안 및 체계를 제시하여야 함 사업수행은 일정에 맞춰서 진행하되 일정이 변경될 경우에는 사전에 발주기관과 협의하여야 함 최종 선정되어 계약체결된 사업자는 계약일로부터 14일 이내에 계약서, 제안요청서,  제안서, 과업지시서 등을 근거로, 본 사업을 수행하기 위한 착수계 등 세부사업추진계획서를 작성·제출하여야 함 사업자는 사업추진과정에서 생산되는 제반 작업 단위별 산출물에 대하여 작업 일정계획 및 품질보증계획과 연계하여 산출물의 종류, 주요내용, 작성 및 제출시기 등을 제시하여야 함 성된 보고서에 대한 오류, 미비점 발견 및 수정 요구 시 즉시 응해야 하며, 추가 요구가 있을 시 이에 응하여야 함 사업의 효율적인 추진을 위해 보고회(착수보고회, 중간보고회, 완료보고회 등), 워크숍 등 위험관리 방안을 제시하여야 함',
    '제안업체 기술의 적합성, 자질 및 활용방안을 입증할 수 있는 증빙자료를 제시하여야 함 공동수급 및 하도급 구성시 참여 기업별로 수행범위 및 역할, 상호 협력 방안 등을 구체적이고 명확하게 정의하고 조직도를 제시하여야 함 제안사는 사업의 안정적이고 효율적인 시스템 구축을 위해 사업수행 책임자(PM)는 주사업자의 직원으로 본 사업을 총괄하여야 하며, 사업 전 기간 동안 상주하여야 함(상주 장소는 발주기관과 협의) 인력이 교체되는 경우 업무의 안정화 및 품질저하 방지대책을 협의하여야 함',
    '사업자는 사업추진 단계에 따라 다음 산출물 등을 작성하여 제출하여야 하며 제출시기 및 부수는 발주기관과 협의하여 제출하여야 함',
    '계약업체는 발주기관으로부터 받은 장비, 서류 및 중간･최종산출물 등 모든 자료를 전량 반납하고 삭제하여야 함 사업완료 시, 계약 상대자는 사업관련 자료를 보유하고 있지 않으며 이를 위반 시 향후 법적책임이 있음을 포함한 ‘대표자명의 보안확약서’를 작성하여 제출 정보통신망 구성도, 정보시스템구성도, 용역사업 산출물 및 개인정보 등은 비공개 자료로 분류하여 관리하여야 함 계약사는 본 사업 관리를 위한 산출물을 추가 요구시에 발주기관에서 요구하는 서식의 형태로 작성하여 제출하여야 함 「소프트웨어산업진흥법 제22조」에 따라 해당 사업 수주자는 SW 사업정보(SW사업 수행 및 실적 정보) 데이터를 작성하여 제출하여야 함 SW사업정보 데이터 작성 및 제출에 관한 사항은 www.spir.kr 자료실의 ‘SW사업정보 저장소 데이터 제출 안내’ 문서를 참조토록 함 SW사업정보 데이터는 사업수행계획서 작성 시 단계별 산출물 리스트에 반드시 명시하도록 함 공급자는 지식재산권의 활용을 위하여 SW산출물의 반출을 요청할 수 있으며, 발주기관에서는 「보안업무규정」 제4조 및 제안요청서에 명시된 누출금지정보에 해당하지 않을 경우 SW산출물을 제공함. 다만, SW산출물의 활용 절차와 공급자가 SW산출물 활용 절차를 지키지 않는 경우 입찰참가자격 제한 등에 관하여는「소프트웨어사업 관리감독에 관한 일반기준」(과학기술정보정통부 고시) 제14조의2(산출물의 활용)에 따름'
    '사업수행을 위한 사업자의 작업공간은 사업자와 발주기관이 상호 협의하여 정함을 원칙으로 하며, 임대료 등 작업장소 운영에 관한 제비용은 제안사가 부담하여야 함 행정안전부 재난안전통신시스템 연계 활용을 위한 공동개발 요건이 발생할 경우 작업장소 운영 등은 발주기관과 상호 협의하여 결정하여야 함 제안사는 원격지 개발에 따른 보안사고 등 위험요인을 식별하여 이에 대한 대응방안을 제안하여야 함 원격지 개발에 따른 개발방법 등에 대한 구체적인 방안을 제시 원격지 개발에 따른 수행 장소 등에 대하여 구체적인 원격지 보안관리대책(시건장치, CCTV 비인가자 출입통제 등)을 마련 프로젝트 사무실, 중요장비 설치장소에 대한 출입보안  개인소유 PC 및 보조기억장치 반입·반출 통제 생성문서는 별도 잠금장치가 된 곳에 보관하며, 안전한 방법에 따라 폐기 문서의 보안등급 부여 및 차별화 된 권한관리를 수행할 것 등 제안사는 작업장소 상호협의 시 제안요청서 내 명시된 보안요구사항을 준수한 작업장소를 제시할 수 있으며, 발주기관에서는 제시된 작업장소에 관하여 우선 검토할 수 있으나 사업자가 제시한 작업장소가 보안상 문제가 있다고 판단되면 발주기관은 작업장소 변경을 요청할 수 있으며 제안사는 이에 응하여야 함 '
    ]

kkma = Twitter()

doc_nouns_list = []

for doc in mydoclist:
    nouns = kkma.nouns(doc)
    doc_nouns = ''
    
    for noun in nouns:
        doc_nouns += noun + ' '
    doc_nouns_list.append(doc_nouns)

#for i in range(0, len(mydoclist)):
#    print('doc' + str(i + 1) + ' : ' + str(doc_nouns_list[i]))
#print(doc_nouns_list)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_nouns_list)
document_distances = (tfidf_matrix * tfidf_matrix.T)

print('우사도 분석을 위한 ' + str(document_distances.get_shape()[0]) + 'x' + str(document_distances.get_shape()[1]) + ' matrix를 만들었습니다.')
print(document_distances.toarray())
# Out:
# 우사도 분석을 위한 5x5 matrix를 만들었습니다.
# [[1.         0.12961156 0.13385006 0.05860638 0.11366785]
#  [0.12961156 1.         0.23165392 0.3240114  0.3050728 ]
#  [0.13385006 0.23165392 1.         0.11030896 0.29674779]
#  [0.05860638 0.3240114  0.11030896 1.         0.28079375]
#  [0.11366785 0.3050728  0.29674779 0.28079375 1.        ]]

# %%
from konlpy.tag import Kkma, Twitter
kkma = Kkma()

def morph(input_data) : #형태소 분석 
    preprocessed = kkma.pos(input_data)
    print(preprocessed)
morph("아메리카노는 맛있다.")
# Out:
# [('아메리카', 'NNG'), ('노', 'NNG'), ('는', 'JX'), ('맛있', 'VA'), ('다', 'EFN'), ('.', 'SF')]

# %%
from konlpy.tag import Kkma, Twitter
kkma = Kkma()
def morph(input_data) :#형태소 분석 
    token_pos = kkma.pos(input_data)
    return token_pos
morph_dic_arr = morph("제안사는 사업을 기간 내에 완수하기 위해 단계별 추진일정 등이 포함된 일정계획을 제시하여야 착수보고서 제출 사업 진행의 모든 일정이 명시된 사업 일정계획표(WBS)를 함께 제출 발주기관의 승인을 받아야 제안사는 일정계획에 따른 관리방안 체계를 제시하여야 사업수행은 일정에 맞춰서 진행하되 일정이 변경될 경우에는 사전에 발주기관과 협의하여야 최종 선정되어 계약체결된 사업자는 계약일로부터 14일 이내에 계약서, 제안요청서, 제안서, 과업지시서 등을 근거로, 사업을 수행하기 위한 착수계 세부사업추진계획서를 작성·제출하여야 사업자는 사업추진과정에서 생산되는 제반 작업 단위별 산출물에 대하여 작업 일정계획 품질보증계획과 연계하여 산출물의 종류, 주요내용, 작성 제출시기 등을 제시하여야 작성된 보고서에 대한 오류, 미비점 발견 수정 요구 즉시 응해야 하며, 추가 요구가 있을 이에 응하여야 사업의 효율적인 추진을 위해 보고회(착수보고회, 중간보고회, 완료보고회 등), 워크숍 위험관리 방안을 제시하여야")
print(morph_dic_arr)
result = []
for obj in morph_dic_arr:
    if obj[1] == 'NNG':
        result.append(obj)
# Out:
# [('제안', 'NNG'), ('사', 'VV'), ('는', 'ETD'), ('사업', 'NNG'), ('을', 'JKO'), ('기간', 'NNG'), ('내', 'NNB'), ('에', 'JKM'), ('완수', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('위하', 'VV'), ('어', 'ECS'), ('단계별', 'NNG'), ('추진', 'NNG'), ('일정', 'NNG'), ('등', 'NNB'), ('이', 'JKS'), ('포함', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('일정', 'NNG'), ('계획', 'NNG'), ('을', 'JKO'), ('제시', 'NNG'), ('하', 'XSV'), ('여야', 'ECD'), ('착수보고서', 'NNG'), ('제출', 'NNG'), ('사업', 'NNG'), ('진행', 'NNG'), ('의', 'JKG'), ('모든', 'NNP'), ('일정', 'NNG'), ('이', 'JKS'), ('명시', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('사업', 'NNG'), ('일정', 'NNG'), ('계획표', 'NNG'), ('(', 'SS'), ('WBS', 'OL'), (')', 'SS'), ('를', 'JKO'), ('함께', 'MAG'), ('제출', 'NNG'), ('발주', 'NNG'), ('기관', 'NNG'), ('의', 'JKG'), ('승인', 'NNG'), ('을', 'JKO'), ('받', 'VV'), ('아야', 'ECD'), ('제안사', 'NNG'), ('는', 'JX'), ('일정', 'NNG'), ('계획', 'NNG'), ('에', 'JKM'), ('따르', 'VV'), ('ㄴ', 'ETD'), ('관리', 'NNG'), ('방안', 'NNG'), ('체계', 'NNG'), ('를', 'JKO'), ('제시', 'NNG'), ('하', 'XSV'), ('여야', 'ECD'), ('사업', 'NNG'), ('수행', 'NNG'), ('은', 'JX'), ('일정', 'NNG'), ('에', 'JKM'), ('맞추', 'VV'), ('어서', 'ECD'), ('진행', 'NNG'), ('하', 'XSV'), ('되', 'ECD'), ('일정', 'NNG'), ('이', 'JKS'), ('변경', 'NNG'), ('되', 'XSV'), ('ㄹ', 'ETD'), ('경우', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('사전', 'NNG'), ('에', 'JKM'), ('발주', 'NNG'), ('기관', 'NNG'), ('과', 'JKM'), ('협의', 'NNG'), ('하', 'XSV'), ('여야', 'ECD'), ('최종', 'NNG'), ('선정', 'NNG'), ('되', 'XSV'), ('어', 'ECD'), ('계약', 'NNG'), ('체결', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('사업자', 'NNG'), ('는', 'JX'), ('계약', 'NNG'), ('일로', 'NNG'), ('부터', 'JX'), ('14', 'NR'), ('일', 'NNM'), ('이내', 'NNG'), ('에', 'JKM'), ('계약서', 'NNG'), (',', 'SP'), ('제안요청서', 'NNG'), (',', 'SP'), ('제안서', 'NNG'), (',', 'SP'), ('과업지시서', 'NNG'), ('등', 'NNB'), ('을', 'JKO'), ('근거', 'NNG'), ('로', 'JKM'), (',', 'SP'), ('사업', 'NNG'), ('을', 'JKO'), ('수행', 'NNG'), ('하', 'XSV'), ('기', 'ETN'), ('위하', 'VV'), ('ㄴ', 'ETD'), ('착수', 'NNG'), ('계', 'XSN'), ('세부', 'NNG'), ('사업', 'NNG'), ('추진', 'NNG'), ('계획서', 'NNG'), ('를', 'JKO'), ('작성', 'NNG'), ('·', 'SP'), ('제출', 'NNG'), ('하', 'XSV'), ('여야', 'ECD'), ('사업자', 'NNG'), ('는', 'JX'), ('사업', 'NNG'), ('추진', 'NNG'), ('과정', 'NNG'), ('에서', 'JKM'), ('생산', 'NNG'), ('되', 'XSV'), ('는', 'ETD'), ('제반', 'NNG'), ('작업', 'NNG'), ('단위', 'NNG'), ('별', 'XSN'), ('산출물', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('여', 'ECS'), ('작업', 'NNG'), ('일정', 'NNG'), ('계획', 'NNG'), ('품질', 'NNG'), ('보증', 'NNG'), ('계획', 'NNG'), ('과', 'JKM'), ('연계', 'NNG'), ('하', 'XSV'), ('여', 'ECS'), ('산출물', 'NNG'), ('의', 'JKG'), ('종류', 'NNG'), (',', 'SP'), ('주요', 'NNG'), ('내용', 'NNG'), (',', 'SP'), ('작성', 'NNG'), ('제출', 'NNG'), ('시기', 'NNG'), ('등', 'NNB'), ('을', 'JKO'), ('제시', 'NNG'), ('하', 'XSV'), ('여야', 'ECD'), ('작성', 'NNG'), ('되', 'XSV'), ('ㄴ', 'ETD'), ('보고서', 'NNG'), ('에', 'JKM'), ('대하', 'VV'), ('ㄴ', 'ETD'), ('오류', 'NNG'), (',', 'SP'), ('미비점', 'NNG'), ('발견', 'NNG'), ('수정', 'NNG'), ('요구', 'NNG'), ('즉시', 'NNG'), ('응하', 'VV'), ('어야', 'ECD'), ('하', 'VV'), ('며', 'ECE'), (',', 'SP'), ('추가', 'NNG'), ('요구', 'NNG'), ('가', 'JKS'), ('있', 'VV'), ('을', 'ETD'), ('이에', 'MAG'), ('응하', 'VV'), ('여야', 'ECD'), ('사업', 'NNG'), ('의', 'JKG'), ('효율', 'NNG'), ('적인', 'NNG'), ('추진', 'NNG'), ('을', 'JKO'), ('위하', 'VV'), ('어', 'ECS'), ('보', 'VV'), ('고', 'ECE'), ('회', 'NNG'), ('(', 'SS'), ('착수보고회', 'NNG'), (',', 'SP'), ('중간', 'NNG'), ('보고회', 'NNG'), (',', 'SP'), ('완료보고회', 'NNG'), ('등', 'NNB'), (')', 'SS'), (',', 'SP'), ('워크숍', 'NNG'), ('위험', 'NNG'), ('관리', 'NNG'), ('방안', 'NNG'), ('을', 'JKO'), ('제시', 'NNG'), ('하', 'XSV'), ('여야', 'ECD')]

# %%
#-*-coding:utf-8-*-
from konlpy.corpus import kolaw
from konlpy.tag import Twitter
from konlpy.utils import pprint

from nltk.collocations import BigramAssocMeasures
from nltk.collocations import TrigramAssocMeasures
from nltk.metrics.association import QuadgramAssocMeasures
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.collocations import QuadgramCollocationFinder

from collections import Counter

ngram = [(BigramAssocMeasures(),BigramCollocationFinder),
         (TrigramAssocMeasures(),TrigramCollocationFinder),
          (QuadgramAssocMeasures(),QuadgramCollocationFinder)]

# s = kolaw.open('constitution.txt').read() # 한국 법률 말뭉치
twit = Twitter()      # loading tagger
nouns = twit.nouns("제안사는 사업을 기간 내에 완수하기 위해 단계별 추진일정 등이 포함된 일정계획을 제시하여야 착수보고서 제출 사업 진행의 모든 일정이 명시된 사업 일정계획표(WBS)를 함께 제출 발주기관의 승인을 받아야 제안사는 일정계획에 따른 관리방안 체계를 제시하여야 사업수행은 일정에 맞춰서 진행하되 일정이 변경될 경우에는 사전에 발주기관과 협의하여야 최종 선정되어 계약체결된 사업자는 계약일로부터 14일 이내에 계약서, 제안요청서, 제안서, 과업지시서 등을 근거로, 사업을 수행하기 위한 착수계 세부사업추진계획서를 작성·제출하여야 사업자는 사업추진과정에서 생산되는 제반 작업 단위별 산출물에 대하여 작업 일정계획 품질보증계획과 연계하여 산출물의 종류, 주요내용, 작성 제출시기 등을 제시하여야 작성된 보고서에 대한 오류, 미비점 발견 수정 요구 즉시 응해야 하며, 추가 요구가 있을 이에 응하여야 사업의 효율적인 추진을 위해 보고회(착수보고회, 중간보고회, 완료보고회 등), 워크숍 위험관리 방안을 제시하여야") # get nouns

founds_from_4measure = []
for measure, finder in ngram:
    finder = finder.from_words(nouns)
    founds = finder.nbest(measure.pmi, 10)       # pmi - 상위 10개 추출
    founds += finder.nbest(measure.chi_sq, 10)   # chi_sq - 상위 10개 추출
    founds += finder.nbest(measure.mi_like, 10)  # mi_like - 상위 10개 추출
    founds += finder.nbest(measure.jaccard, 10)  # jaccard - 상위 10개 추출

    founds_from_4measure += founds

collocations = [' '.join(collocation) for collocation in founds_from_4measure]
collocations = [(w,f) for w,f in Counter(collocations).most_common() if f > 2]
pprint(collocations)
# Out:
# [('경우 사전', 4),
#  ('계약서 제안요청서', 4),
#  ('과업 지시', 4),
#  ('과정 생산', 4),
#  ('기간 내', 4),
#  ('내 완수', 4),
#  ('대한 오류', 4),
#  ('과정 생산 제반', 4),
#  ('기간 내 완수', 4),
#  ('대한 오류 미비', 4),
#  ('물의 종류 내용', 4),
#  ('미비 점 발견', 4),
#  ('변경 경우 사전', 4),
#  ('오류 미비 점', 4),
#  ('이내 계약서 제안요청서', 4),
#  ('일로 이내 계약서', 4),
#  ('점 발견 수정', 4),
#  ('대한 오류 미비 점', 4),
#  ('미비 점 발견 수정', 4),
#  ('오류 미비 점 발견', 4),
#  ('일로 이내 계약서 제안요청서', 4),
#  ('계 산출 물의 종류', 4),
#  ('계약 일로 이내 계약서', 4),
#  ('과정 생산 제반 작업', 4),
#  ('기간 내 완수 위해', 4),
#  ('기관 협의 최종 선정', 4),
#  ('물 대하', 3),
#  ('물의 종류', 3),
#  ('미비 점', 3),
#  ('내 완수 위해 단계', 3)]

# %% [markdown]
# ## 제안서 형태서 분석

# %%
import json

# with를 이용해 파일을 연다.
# json 파일은 같은 폴더에 있다고 가정!

arr = []
arr.append('제안사는 사업을 기간 내에 완수하기 위해 단계별 추진일정 등이 포함된 일정계획을 제시하여야 착수보고서 제출 사업 진행의 모든 일정이 명시된 사업 일정계획표(WBS)를 함께 제출 발주기관의 승인을 받아야 제안사는 일정계획에 따른 관리방안 체계를 제시하여야 사업수행은 일정에 맞춰서 진행하되 일정이 변경될 경우에는 사전에 발주기관과 협의하여야 최종 선정되어 계약체결된 사업자는 계약일로부터 14일 이내에 계약서, 제안요청서, 제안서, 과업지시서 등을 근거로, 사업을 수행하기 위한 착수계 세부사업추진계획서를 작성·제출하여야 사업자는 사업추진과정에서 생산되는 제반 작업 단위별 산출물에 대하여 작업 일정계획 품질보증계획과 연계하여 산출물의 종류, 주요내용, 작성 제출시기 등을 제시하여야 작성된 보고서에 대한 오류, 미비점 발견 수정 요구 즉시 응해야 하며, 추가 요구가 있을 이에 응하여야 사업의 효율적인 추진을 위해 보고회(착수보고회, 중간보고회, 완료보고회 등), 워크숍 위험관리 방안을 제시하여야')
with open('db.json', encoding="utf8") as json_file:
    json_data = json.load(json_file)

    # key가 json_string인 문자열 가져오기
    json_string = json_data["rfp"]
    for obj in json_string:
        prjId = obj['prjId']
        reqDefi = obj['reqDefi']
        detInfo = obj['detInfo']
        fullNum = obj['fullNum']
        reqName = obj['reqName']
        type = obj['type']
        id = obj['id']
        
        arr.append(detInfo)
print(arr)
# Out:
# ['제안사는 사업을 기간 내에 완수하기 위해 단계별 추진일정 등이 포함된 일정계획을 제시하여야 착수보고서 제출 사업 진행의 모든 일정이 명시된 사업 일정계획표(WBS)를 함께 제출 발주기관의 승인을 받아야 제안사는 일정계획에 따른 관리방안 체계를 제시하여야 사업수행은 일정에 맞춰서 진행하되 일정이 변경될 경우에는 사전에 발주기관과 협의하여야 최종 선정되어 계약체결된 사업자는 계약일로부터 14일 이내에 계약서, 제안요청서, 제안서, 과업지시서 등을 근거로, 사업을 수행하기 위한 착수계 세부사업추진계획서를 작성·제출하여야 사업자는 사업추진과정에서 생산되는 제반 작업 단위별 산출물에 대하여 작업 일정계획 품질보증계획과 연계하여 산출물의 종류, 주요내용, 작성 제출시기 등을 제시하여야 작성된 보고서에 대한 오류, 미비점 발견 수정 요구 즉시 응해야 하며, 추가 요구가 있을 이에 응하여야 사업의 효율적인 추진을 위해 보고회(착수보고회, 중간보고회, 완료보고회 등), 워크숍 위험관리 방안을 제시하여야', '디지털트윈 기능 인터페이스 개념 정의 디지털트윈 플랫폼의 시스템 사용자 운용성을 높이기 위한 범위로 연계시스템과의 송수신 시스템 연계표준을 준용한 연동 방식을 구성함 플랫폼과 연계시스템간의 운영 성능에 미치는 영향을 고려하여 갱신주기 연계 어플리케이션 실행 시간 등을 설정하여야 시스템 인터페이스 요구사항 어플리케이션과 정보 간의 상호작용을 하는 기능은 기능 구현의 정확성 뿐만 아니라 정보의 무결성, 데이터 정합성을 검증받아야 연계 시스템의 재개발 환경 변화에 따른 기술 지원 추가 연계 발생에 필요한 인터페이스 규격 제공, 테스트 등을 지원해야', '디지털트윈 플랫폼을 활용한 서비스 지원 연계 인터페이스 구성 지원 신규 외부서비스 지원을 위한 연계 인터페이스 구성시 디지털트윈 플랫폼 운영 성능에 이슈발생이 되지 않도록 인터페이스를 구성 제공함 자료의 제공 연계방식은 스마트시티 통합플랫폼 데이터교환 표준 연계방식을 우선 검토하며, 필요시 추가 운영방식을 제공할 있음 상황이벤트/복합 상황이벤트의 송수신은 네트워크(Network) 방식으로 하며, 네트워크 방식에는 Socket 방식, HTTP 방식, Web Service 방식 가지를 선택하여 연계함 이벤트 메시지 교환은 One-Way, One-way ack Request-Response를 정보유형에 따라 사용함 디지털트윈 기본데이터는 데이터베이스 연결방식으로 연계하며, 필요시 Open-API 방식을 고려할 있음', '데이터 연계 모니터링 데이터 현행화 디지털트윈 플랫폼과 연계된 중앙부처 공공기관 간의 데이터 갱신 품질관리를 위한 수시 모니터링 데이터 현행화 관리 연계시스템에게 자료 제공시 요청자료의 정확한 전송을 위한 목록 일정 관리 대용량 자료 변동분 자료 제공에 대한 스케줄 설정 관리, 자료전송 지연에 대한 대응 연계데이터 갱신 관리 안정적 성능유지 사용자 정보 증가 시에도 안정적인 성능제공을 위한 방안을 마련해야 서비스 수요에 대응하기 위해 범부처간 공간정보 연계 가능 시스템 수요조사, 업무협의, 시스템 연계, 공간정보 연계 운영 등을 지원 디지털트윈 업무활용기관을 대상으로 표준화된 조사서식을 제공하고, 조사결과 취합 공개 지원 지자체 정보화기본계획 관련 계획 수립 연계가능성 검토를 위한 정보 수집 목록화 지원 IOT 기기 실시간 연동자료에 대한 온라인 연계 확대는 표준자료연계모듈을 기반으로 하며, 연계주기, 자료목록 등은 상세 협의로 결정 세부 업무내용 일정 등은 발주기관과 협의하여 진행', '시스템 인터페이스 구성 요건 디지털트윈 정보 요청을 위한 인터페이스는 OWS(OGC Web Service) 표준이나 OGC API 표준을 준수하여 제공해야 함.** 추가 서비스를 위한 정보제공 인터페이스 구현시 관련 기술 표준을 우선 적용하여 구축하도록 검토함 디지털트윈 IT 구현 관점에서 공공정보의 개방 활용에 대한 기술의 표준화된 방식으로 개발하고 보안문제에 취약하지 않도록 인터페이스 구현', '디지털트윈 플랫폼 활용범위 기반의 연계시스템 구성 지원 디지털트윈 플랫폼 기반데이터 구축 운영을 위한 도시정보 연계 대상 선정 도시계획·설계·시공·관리운영에 필요한 공간정보 선정 연계 인터페이스 정의 대표 기반정보로 지적, 지형, 토지 건축물, 도시계획현황, 토지이용계획, 지구단위계획 등을 인터페이스로 연계 지원해야', '사용자 인터페이스 구성 요건 내부서비스 유사 공통서비스에 대한 유기적 연계 정보구성방안 제시․구축 업무 효율성 향상을 위하여 최신 기술이 적용된 사용자 인터페이스 적용과 사용자 중심의 화면설계 업무기능 제공 향후 확장 개편이 용이하도록 메뉴구조와 DB 구조 설계 다양한 사용자 접속을 고려하며, 사용함에 불편함이 없는 접속 속도를 보장할 있도록 웹디자인 설계 정보공개방식 개선, 수요자 관점 서비스 개편 정보의 개방, 공유, 소통, 협력을 위한 서비스 방안을 제시하고 구현하여야 Open-API 서비스는 디지털트윈 플랫폼에서 운영 중인 서비스와 일관성 있는 UI를 적용해야 단, 데이터 Open-API 서비스를 활용하는 경우 독자적인 서비스 UI를 구성할 있으나, 지도서비스의 경우 일관성 있는 UI를 적용해야 정보기술에 대한 미숙련자도 쉽게 사용가능하고 직관적인 사용자 인터페이스를 구현해야 담당자 또는 관리자 사용자 매뉴얼을 제공해야 기타 상세한 사항에 대해서는 발주자와 협의하여 결정하여야', '전자정부서비스 호환성 준수 UI는 웹접근성 향상을 위한 국가표준기술 가이드라인 전자정부서비스 호환성 준수지침(행정안전부고시 제2017-26호) 준수 필요 웹접근성은 장애인차별금지법을 고려한 의무사항 준수 필요하나 GIS 시스템의 특성상 일부 예외를 지정할 있음. PC의 최신 OS 인터넷 브라우저 (HTML5 WebGL표준을 준수하는 브라우저 에서도 프로그램이 보안 등에 문제없이 원활하게 작동하도록 개발※ 단, 시스템의 보안성 강화를 위해 별도로 운영되는 각종 보안프로그램 등의 호환성 미비로 브라우저의 확대 적용이 불가능할 경우에는 별도의 협의를 통해 적용 범위 조정 가능 전자정부프레임워크를 활용하지 않을 경우 합당한 사유를 제시할', '디지털트윈 단위모듈별 인터페이스 다양한 계층의 아키텍처로 구성되는 디지털트윈 플랫폼 특성상 개별 단위모듈(계층)간 요건에 맞는 인터페이스를 정의하고 관리하도록 관리되는 구분은 국가시범도시 디지털트윈 ISMP에서 구성된 아키텍처 구성계층을 기본으로 하며, 필요시 추가 또는 변경 사용가능하나 구성변경에 대한 이력관리를 별도로 함* 아키텍처 구성계층Edge Layer, SENSING/Resource Layer, DATA Layer,DT Cloud Infra(HW/SW), BUSINESS PROCESSING Layer,Application Layer, Display Layer 디지털트윈 통합인터페이스 관리 개별 인터페이스 시스템의 공통활용/연계 기능을 관리 레벨로 통합하여 하나의 아키텍처에서 통합적으로 관리함 개별 인터페이스 구성의 복잡성을 해소하기 위해 통합 인터페이스 관리체계 구성시 사용자 요구사항 관리요구항목을 기준으로 대시보드 형태로 구성함', '국정원, 국토부, 공사 보안규정 지침을 준수하여 개발이 수행되어야 계약상대자가 원격지 개발을 희망할 경우 보안사고 위험요인을 식별하여 이에 대한 대응방안을 제안하고, 제안요청서에 명시한 보안요구사항 등을 준수하여 원격지 개발에 따른 구체적인 원격지 보안관리대책(참여 인원, 원격지 개발장소 장비, 원격지 개발 장소의 노트북·USB 휴대용 저장매체, 네트워크, 자료 등)을 제시하여야 발주기관에서는 공급자가 제시한 작업장소가 보안요구사항을 준수하지 못한 경우 거부할 있음 모든 성과품은 계약 상대자가 소유하거나 임의로 복사 또는 외부로 유출해서는 된다. 또한 과업 수행상의 비밀 (기밀 등) 엄수하여야 하며, 비밀의 유출 임의 사용으로 인한 문제발생 민사․형사 손해배상 책임을 착수신고서 제출 계약 상대자 (용역사 대표) 용역 참여자의 자필로 서명한 보안각서를 함께 제출하여야 과업수행 장소는 과업 내용의 중요도에 따라 통제구역 또는 제한구역으로 지정하고 외부인의 출입을 통제하여야 하며, 통제구역 출입자 명부를 비치하고 출입 통제 사항 ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Kkma, Twitter
from konlpy.utils import pprint

# 0 번째는 검증하고 싶은 문자.
# n 번째는 대조군
kkma = Kkma()

mydoclist = arr
doc_nouns_list = []
for doc in mydoclist:
    nouns = kkma.nouns(doc)
    doc_nouns = ''
    
    for noun in nouns:
        doc_nouns += noun + ' '
    doc_nouns_list.append(doc_nouns)

# %%
print('doc' + str(0) + ' : ' + str(doc_nouns_list[0]))
# Out:
# doc0 : 제안 사업 기간 내 완수 단계별 추진 추진일정 일정 등 포함 일정계획 계획 제시 착수 착수보고서 보고서 제출 진행 모든 명시 일정계획표 계획표 발주 발주기관 기관 승인 관리 관리방안 방안 체계 사업수행 수행 변경 경우 사전 협의 최종 선정 계약 계약체결 체결 사업자 계약일로 일로 14 14일 일 이내 계약서 제안요청서 요청서 제안서 과업 과업지시서 지시서 근거 세부 세부사업추진계획서 계획서 작성 사업추진과정 과정 생산 제반 작업 단위 산출물 품질 품질보증계획 보증 연계 종류 주요 주요내용 내용 제출시기 시기 오류 미비점 발견 수정 요구 즉시 추가 효율 효율적인 적인 회 착수보고회 보고회 중간 중간보고회 완료 완료보고회 워크숍 위험 위험관리

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_nouns_list)
document_distances = (tfidf_matrix * tfidf_matrix.T)

print('우사도 분석을 위한 ' + str(document_distances.get_shape()[0]) + 'x' + str(document_distances.get_shape()[1]) + ' matrix를 만들었습니다.')
#print(document_distances.toarray())
# Out:
# 우사도 분석을 위한 37x37 matrix를 만들었습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
print("Seaborn version : ", sns.__version__)
sns.set()
sns.set_style('whitegrid')
sns.set_color_codes()

current_palette = sns.color_palette()
sns.palplot(current_palette)

print("Matplotlib version", matplotlib.__version__)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.figure(figsize=(47, 47))
ax = sns.heatmap(document_distances.toarray(), annot=True)

figure = ax.get_figure()    
figure.savefig('svm_conf.png')
# Out:
# Seaborn version :  0.9.0
# Matplotlib version 3.1.0

# %%
print(tfidf_matrix.shape)
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
# 유사도를 구함
sim_scores = list(enumerate(cosine_sim[0]))
# 유사도에 따라 정렬
sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
# 유사도에 대해서 인덱스 받아옴
movie_indices = [i[0] for i in sim_scores]
#유사도에 따라 10개 자름
sim_scores = sim_scores[1:11]
print(sim_scores)
# Out:
# (37, 609)
# [(29, 0.5449146547150404), (24, 0.4694947919550059), (28, 0.46896675907062524), (36, 0.3384378446118767), (34, 0.2145908695221551), (31, 0.2025057067236945), (27, 0.1848497315876842), (9, 0.16717703799579606), (25, 0.16472976510306395), (26, 0.1619512374828567)]
